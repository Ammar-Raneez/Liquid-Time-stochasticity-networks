# %%
import requests
import json

class Scraper:
    def __init__(self):
        self._prices = []
        self._BASE_URL = 'http://api.scraperlink.com/investpy/?email=your@email.com&type=historical_data&product=cryptos&symbol=BTC'
    
    def get_crypto_data(self, start, end):
        '''
        Scrape data current solution
        Possible to break in future, therefore must create a dedicated scraper, if time permits
        '''
        response = requests.request(
            'GET',
            f'{self._BASE_URL}&from_date={start}&to_date={end}'
        )
        self._prices = response.json()['data']

    def get_prices(self):
        '''
        Returns the obtained prices from the API
        '''
        return self._prices
        
    def export_data(self):
        '''
        Export obtained data as JSON so it can be used by the model
        '''
        json_data = json.dumps(self._prices, indent=4)
        with open ('prices.json', 'w') as file:
            file.write(json_data)
        
# API reference: http://api.scraperlink.com/investpy/

# %%
scraper = Scraper()

# %%
scraper.get_crypto_data('09/27/2017', '09/28/2022')

# %%
scraper.get_prices()
# Out:
# [{'direction_color': 'greenFont',
#   'rowDate': 'Sep 28, 2022',
#   'rowDateRaw': 1664323200,
#   'rowDateTimestamp': '2022-09-28T00:00:00Z',
#   'last_close': '19,411.0',
#   'last_open': '19,083.4',
#   'last_max': '19,757.8',
#   'last_min': '18,505.3',
#   'volume': '581.19K',
#   'volumeRaw': 581187,
#   'change_precent': '1.73',
#   'last_closeRaw': '19410.95507812500000',
#   'last_openRaw': '19083.36718750000000',
#   'last_maxRaw': '19757.81835937500000',
#   'last_minRaw': '18505.34375000000000',
#   'change_precentRaw': 1.7292545040826166},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 27, 2022',
#   'rowDateRaw': 1664236800,
#   'rowDateTimestamp': '2022-09-27T00:00:00Z',
#   'last_close': '19,081.0',
#   'last_open': '19,228.8',
#   'last_max': '20,361.2',
#   'last_min': '18,850.4',
#   'volume': '660.12K',
#   'volumeRaw': 660115,
#   'change_precent': '-0.75',
#   'last_closeRaw': '19080.99609375000000',
#   'last_openRaw': '19228.77148437500000',
#   'last_maxRaw': '20361.21484375000000',
#   'last_minRaw': '18850.42187500000000',
#   'change_precentRaw': -0.7525538555813412},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 26, 2022',
#   'rowDateRaw': 1664150400,
#   'rowDateTimestamp': '2022-09-26T00:00:00Z',
#   'last_close': '19,225.7',
#   'last_open': '18,803.1',
#   'last_max': '19,304.8',
#   'last_min': '18,695.2',
#   'volume': '516.03K',
#   'volumeRaw': 516032,
#   'change_precent': '2.25',
#   'last_closeRaw': '19225.67968750000000',
#   'last_openRaw': '18803.09960937500000',
#   'last_maxRaw': '19304.77343750000000',
#   'last_minRaw': '18695.17968750000000',
#   'change_precentRaw': 2.246992253738746},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 25, 2022',
#   'rowDateRaw': 1664064000,
#   'rowDateTimestamp': '2022-09-25T00:00:00Z',
#   'last_close': '18,803.2',
#   'last_open': '18,925.1',
#   'last_max': '19,125.1',
#   'last_min': '18,659.6',
#   'volume': '209.71K',
#   'volumeRaw': 209712,
#   'change_precent': '-0.64',
#   'last_closeRaw': '18803.17382812500000',
#   'last_openRaw': '18925.14453125000000',
#   'last_maxRaw': '19125.06640625000000',
#   'last_minRaw': '18659.61523437500000',
#   'change_precentRaw': -0.6447773110050237},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 24, 2022',
#   'rowDateRaw': 1663977600,
#   'rowDateTimestamp': '2022-09-24T00:00:00Z',
#   'last_close': '18,925.2',
#   'last_open': '19,288.4',
#   'last_max': '19,310.6',
#   'last_min': '18,812.0',
#   'volume': '258.50K',
#   'volumeRaw': 258501,
#   'change_precent': '-1.91',
#   'last_closeRaw': '18925.19921875000000',
#   'last_openRaw': '19288.39453125000000',
#   'last_maxRaw': '19310.55664062500000',
#   'last_minRaw': '18811.95507812500000',
#   'change_precentRaw': -1.9091059190513662},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 23, 2022',
#   'rowDateRaw': 1663891200,
#   'rowDateTimestamp': '2022-09-23T00:00:00Z',
#   'last_close': '19,293.5',
#   'last_open': '19,404.1',
#   'last_max': '19,477.3',
#   'last_min': '18,554.8',
#   'volume': '431.15K',
#   'volumeRaw': 431149,
#   'change_precent': '-0.57',
#   'last_closeRaw': '19293.53320312500000',
#   'last_openRaw': '19404.09765625000000',
#   'last_maxRaw': '19477.26562500000000',
#   'last_minRaw': '18554.81445312500000',
#   'change_precentRaw': -0.5691890063218954},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 22, 2022',
#   'rowDateRaw': 1663804800,
#   'rowDateTimestamp': '2022-09-22T00:00:00Z',
#   'last_close': '19,404.0',
#   'last_open': '18,488.1',
#   'last_max': '19,490.9',
#   'last_min': '18,371.0',
#   'volume': '448.63K',
#   'volumeRaw': 448633,
#   'change_precent': '4.95',
#   'last_closeRaw': '19403.97851562500000',
#   'last_openRaw': '18488.09570312500000',
#   'last_maxRaw': '19490.91406250000000',
#   'last_minRaw': '18371.00781250000000',
#   'change_precentRaw': 4.948838846433297},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 21, 2022',
#   'rowDateRaw': 1663718400,
#   'rowDateTimestamp': '2022-09-21T00:00:00Z',
#   'last_close': '18,489.0',
#   'last_open': '18,875.1',
#   'last_max': '19,758.4',
#   'last_min': '18,191.8',
#   'volume': '446.85K',
#   'volumeRaw': 446852,
#   'change_precent': '-2.03',
#   'last_closeRaw': '18488.98828125000000',
#   'last_openRaw': '18875.11718750000000',
#   'last_maxRaw': '19758.40820312500000',
#   'last_minRaw': '18191.75195312500000',
#   'change_precentRaw': -2.0316833523463527},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 20, 2022',
#   'rowDateRaw': 1663632000,
#   'rowDateTimestamp': '2022-09-20T00:00:00Z',
#   'last_close': '18,872.4',
#   'last_open': '19,538.9',
#   'last_max': '19,626.3',
#   'last_min': '18,742.6',
#   'volume': '361.18K',
#   'volumeRaw': 361180,
#   'change_precent': '-3.41',
#   'last_closeRaw': '18872.41601562500000',
#   'last_openRaw': '19538.85156250000000',
#   'last_maxRaw': '19626.32031250000000',
#   'last_minRaw': '18742.59375000000000',
#   'change_precentRaw': -3.4108225078799332},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 19, 2022',
#   'rowDateRaw': 1663545600,
#   'rowDateTimestamp': '2022-09-19T00:00:00Z',
#   'last_close': '19,538.9',
#   'last_open': '19,417.4',
#   'last_max': '19,666.6',
#   'last_min': '18,277.8',
#   'volume': '423.43K',
#   'volumeRaw': 423428,
#   'change_precent': '0.62',
#   'last_closeRaw': '19538.85156250000000',
#   'last_openRaw': '19417.38476562500000',
#   'last_maxRaw': '19666.62109375000000',
#   'last_minRaw': '18277.76562500000000',
#   'change_precentRaw': 0.6180169346657755},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 18, 2022',
#   'rowDateRaw': 1663459200,
#   'rowDateTimestamp': '2022-09-18T00:00:00Z',
#   'last_close': '19,418.8',
#   'last_open': '20,113.9',
#   'last_max': '20,113.9',
#   'last_min': '19,347.7',
#   'volume': '273.11K',
#   'volumeRaw': 273109,
#   'change_precent': '-3.45',
#   'last_closeRaw': '19418.83984375000000',
#   'last_openRaw': '20113.89843750000000',
#   'last_maxRaw': '20113.89843750000000',
#   'last_minRaw': '19347.66406250000000',
#   'change_precentRaw': -3.4537947792811154},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 17, 2022',
#   'rowDateRaw': 1663372800,
#   'rowDateTimestamp': '2022-09-17T00:00:00Z',
#   'last_close': '20,113.5',
#   'last_open': '19,802.8',
#   'last_max': '20,178.6',
#   'last_min': '19,761.0',
#   'volume': '204.58K',
#   'volumeRaw': 204579,
#   'change_precent': '1.57',
#   'last_closeRaw': '20113.51953125000000',
#   'last_openRaw': '19802.81835937500000',
#   'last_maxRaw': '20178.58203125000000',
#   'last_minRaw': '19760.96875000000000',
#   'change_precentRaw': 1.5712084838275067},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 16, 2022',
#   'rowDateRaw': 1663286400,
#   'rowDateTimestamp': '2022-09-16T00:00:00Z',
#   'last_close': '19,802.4',
#   'last_open': '19,701.9',
#   'last_max': '19,883.0',
#   'last_min': '19,352.9',
#   'volume': '315.59K',
#   'volumeRaw': 315586,
#   'change_precent': '0.51',
#   'last_closeRaw': '19802.38281250000000',
#   'last_openRaw': '19701.94921875000000',
#   'last_maxRaw': '19883.04492187500000',
#   'last_minRaw': '19352.89843750000000',
#   'change_precentRaw': 0.5108508341537553},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 15, 2022',
#   'rowDateRaw': 1663200000,
#   'rowDateTimestamp': '2022-09-15T00:00:00Z',
#   'last_close': '19,701.7',
#   'last_open': '20,222.3',
#   'last_max': '20,321.4',
#   'last_min': '19,532.3',
#   'volume': '358.42K',
#   'volumeRaw': 358423,
#   'change_precent': '-2.58',
#   'last_closeRaw': '19701.73632812500000',
#   'last_openRaw': '20222.31445312500000',
#   'last_maxRaw': '20321.36523437500000',
#   'last_minRaw': '19532.28515625000000',
#   'change_precentRaw': -2.5751037313139484},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 14, 2022',
#   'rowDateRaw': 1663113600,
#   'rowDateTimestamp': '2022-09-14T00:00:00Z',
#   'last_close': '20,222.5',
#   'last_open': '20,175.5',
#   'last_max': '20,503.7',
#   'last_min': '19,654.2',
#   'volume': '374.22K',
#   'volumeRaw': 374221,
#   'change_precent': '0.23',
#   'last_closeRaw': '20222.48632812500000',
#   'last_openRaw': '20175.49414062500000',
#   'last_maxRaw': '20503.69335937500000',
#   'last_minRaw': '19654.16015625000000',
#   'change_precentRaw': 0.23276190627393242},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 13, 2022',
#   'rowDateRaw': 1663027200,
#   'rowDateTimestamp': '2022-09-13T00:00:00Z',
#   'last_close': '20,175.5',
#   'last_open': '22,395.3',
#   'last_max': '22,702.5',
#   'last_min': '19,909.6',
#   'volume': '485.32K',
#   'volumeRaw': 485324,
#   'change_precent': '-9.91',
#   'last_closeRaw': '20175.52539062500000',
#   'last_openRaw': '22395.25585937500000',
#   'last_maxRaw': '22702.47851562500000',
#   'last_minRaw': '19909.63476562500000',
#   'change_precentRaw': -9.91186949282443},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 12, 2022',
#   'rowDateRaw': 1662940800,
#   'rowDateTimestamp': '2022-09-12T00:00:00Z',
#   'last_close': '22,395.3',
#   'last_open': '21,836.6',
#   'last_max': '22,465.4',
#   'last_min': '21,581.6',
#   'volume': '431.98K',
#   'volumeRaw': 431981,
#   'change_precent': '2.57',
#   'last_closeRaw': '22395.32031250000000',
#   'last_openRaw': '21836.57226562500000',
#   'last_maxRaw': '22465.36328125000000',
#   'last_minRaw': '21581.59960937500000',
#   'change_precentRaw': 2.5664135722803865},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 11, 2022',
#   'rowDateRaw': 1662854400,
#   'rowDateTimestamp': '2022-09-11T00:00:00Z',
#   'last_close': '21,834.9',
#   'last_open': '21,650.4',
#   'last_max': '21,836.4',
#   'last_min': '21,363.0',
#   'volume': '297.12K',
#   'volumeRaw': 297118,
#   'change_precent': '0.85',
#   'last_closeRaw': '21834.94531250000000',
#   'last_openRaw': '21650.41406250000000',
#   'last_maxRaw': '21836.39257812500000',
#   'last_minRaw': '21363.02343750000000',
#   'change_precentRaw': 0.8523220362774528},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 10, 2022',
#   'rowDateRaw': 1662768000,
#   'rowDateTimestamp': '2022-09-10T00:00:00Z',
#   'last_close': '21,650.4',
#   'last_open': '21,363.8',
#   'last_max': '21,790.6',
#   'last_min': '21,139.9',
#   'volume': '331.12K',
#   'volumeRaw': 331121,
#   'change_precent': '1.33',
#   'last_closeRaw': '21650.41406250000000',
#   'last_openRaw': '21363.77148437500000',
#   'last_maxRaw': '21790.55859375000000',
#   'last_minRaw': '21139.86132812500000',
#   'change_precentRaw': 1.334718955751651},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 09, 2022',
#   'rowDateRaw': 1662681600,
#   'rowDateTimestamp': '2022-09-09T00:00:00Z',
#   'last_close': '21,365.2',
#   'last_open': '19,318.8',
#   'last_max': '21,545.7',
#   'last_min': '19,294.1',
#   'volume': '480.37K',
#   'volumeRaw': 480373,
#   'change_precent': '10.60',
#   'last_closeRaw': '21365.24804687500000',
#   'last_openRaw': '19318.78125000000000',
#   'last_maxRaw': '21545.65429687500000',
#   'last_minRaw': '19294.08593750000000',
#   'change_precentRaw': 10.601141438638953},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 08, 2022',
#   'rowDateRaw': 1662595200,
#   'rowDateTimestamp': '2022-09-08T00:00:00Z',
#   'last_close': '19,317.4',
#   'last_open': '19,281.5',
#   'last_max': '19,444.7',
#   'last_min': '19,034.5',
#   'volume': '291.43K',
#   'volumeRaw': 291427,
#   'change_precent': '0.19',
#   'last_closeRaw': '19317.38476562500000',
#   'last_openRaw': '19281.51367187500000',
#   'last_maxRaw': '19444.68554687500000',
#   'last_minRaw': '19034.52539062500000',
#   'change_precentRaw': 0.18608952677892207},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 07, 2022',
#   'rowDateRaw': 1662508800,
#   'rowDateTimestamp': '2022-09-07T00:00:00Z',
#   'last_close': '19,281.5',
#   'last_open': '18,786.3',
#   'last_max': '19,445.9',
#   'last_min': '18,548.4',
#   'volume': '319.10K',
#   'volumeRaw': 319101,
#   'change_precent': '2.64',
#   'last_closeRaw': '19281.50390625000000',
#   'last_openRaw': '18786.25585937500000',
#   'last_maxRaw': '19445.88281250000000',
#   'last_minRaw': '18548.37695312500000',
#   'change_precentRaw': 2.6355424739934294},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 06, 2022',
#   'rowDateRaw': 1662422400,
#   'rowDateTimestamp': '2022-09-06T00:00:00Z',
#   'last_close': '18,786.4',
#   'last_open': '19,793.4',
#   'last_max': '20,169.3',
#   'last_min': '18,723.3',
#   'volume': '402.43K',
#   'volumeRaw': 402433,
#   'change_precent': '-5.09',
#   'last_closeRaw': '18786.38085937500000',
#   'last_openRaw': '19793.41992187500000',
#   'last_maxRaw': '20169.28710937500000',
#   'last_minRaw': '18723.33398437500000',
#   'change_precentRaw': -5.086173235749571},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 05, 2022',
#   'rowDateRaw': 1662336000,
#   'rowDateTimestamp': '2022-09-05T00:00:00Z',
#   'last_close': '19,793.1',
#   'last_open': '19,999.9',
#   'last_max': '20,042.9',
#   'last_min': '19,650.7',
#   'volume': '238.71K',
#   'volumeRaw': 238711,
#   'change_precent': '-1.03',
#   'last_closeRaw': '19793.09179687500000',
#   'last_openRaw': '19999.94140625000000',
#   'last_maxRaw': '20042.89648437500000',
#   'last_minRaw': '19650.71875000000000',
#   'change_precentRaw': -1.0342510769074518},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 04, 2022',
#   'rowDateRaw': 1662249600,
#   'rowDateTimestamp': '2022-09-04T00:00:00Z',
#   'last_close': '19,999.9',
#   'last_open': '19,832.2',
#   'last_max': '20,017.8',
#   'last_min': '19,594.7',
#   'volume': '158.27K',
#   'volumeRaw': 158267,
#   'change_precent': '0.85',
#   'last_closeRaw': '19999.94140625000000',
#   'last_openRaw': '19832.19335937500000',
#   'last_maxRaw': '20017.83789062500000',
#   'last_minRaw': '19594.68945312500000',
#   'change_precentRaw': 0.8497105437400954},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 03, 2022',
#   'rowDateRaw': 1662163200,
#   'rowDateTimestamp': '2022-09-03T00:00:00Z',
#   'last_close': '19,831.4',
#   'last_open': '19,952.8',
#   'last_max': '20,043.8',
#   'last_min': '19,660.7',
#   'volume': '157.85K',
#   'volumeRaw': 157854,
#   'change_precent': '-0.61',
#   'last_closeRaw': '19831.43164062500000',
#   'last_openRaw': '19952.75195312500000',
#   'last_maxRaw': '20043.75976562500000',
#   'last_minRaw': '19660.66406250000000',
#   'change_precentRaw': -0.6077655736746902},
#  {'direction_color': 'redFont',
#   'rowDate': 'Sep 02, 2022',
#   'rowDateRaw': 1662076800,
#   'rowDateTimestamp': '2022-09-02T00:00:00Z',
#   'last_close': '19,952.7',
#   'last_open': '20,131.6',
#   'last_max': '20,428.2',
#   'last_min': '19,764.7',
#   'volume': '272.22K',
#   'volumeRaw': 272220,
#   'change_precent': '-0.86',
#   'last_closeRaw': '19952.69726562500000',
#   'last_openRaw': '20131.59179687500000',
#   'last_maxRaw': '20428.16406250000000',
#   'last_minRaw': '19764.73242187500000',
#   'change_precentRaw': -0.8613966809205725},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Sep 01, 2022',
#   'rowDateRaw': 1661990400,
#   'rowDateTimestamp': '2022-09-01T00:00:00Z',
#   'last_close': '20,126.1',
#   'last_open': '20,049.9',
#   'last_max': '20,202.7',
#   'last_min': '19,584.4',
#   'volume': '275.08K',
#   'volumeRaw': 275079,
#   'change_precent': '0.41',
#   'last_closeRaw': '20126.06250000000000',
#   'last_openRaw': '20049.87890625000000',
#   'last_maxRaw': '20202.68359375000000',
#   'last_minRaw': '19584.44140625000000',
#   'change_precentRaw': 0.41000862658072373},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 31, 2022',
#   'rowDateRaw': 1661904000,
#   'rowDateTimestamp': '2022-08-31T00:00:00Z',
#   'last_close': '20,043.9',
#   'last_open': '19,793.4',
#   'last_max': '20,469.1',
#   'last_min': '19,793.4',
#   'volume': '318.17K',
#   'volumeRaw': 318166,
#   'change_precent': '1.27',
#   'last_closeRaw': '20043.88085937500000',
#   'last_openRaw': '19793.44335937500000',
#   'last_maxRaw': '20469.07617187500000',
#   'last_minRaw': '19793.44335937500000',
#   'change_precentRaw': 1.269551747205124},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 30, 2022',
#   'rowDateRaw': 1661817600,
#   'rowDateTimestamp': '2022-08-30T00:00:00Z',
#   'last_close': '19,792.6',
#   'last_open': '20,295.6',
#   'last_max': '20,558.2',
#   'last_min': '19,559.7',
#   'volume': '308.41K',
#   'volumeRaw': 308410,
#   'change_precent': '-2.48',
#   'last_closeRaw': '19792.60351562500000',
#   'last_openRaw': '20295.61914062500000',
#   'last_maxRaw': '20558.18750000000000',
#   'last_minRaw': '19559.74804687500000',
#   'change_precentRaw': -2.479307746205558},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 29, 2022',
#   'rowDateRaw': 1661731200,
#   'rowDateTimestamp': '2022-08-29T00:00:00Z',
#   'last_close': '20,295.8',
#   'last_open': '19,551.3',
#   'last_max': '20,394.5',
#   'last_min': '19,551.2',
#   'volume': '248.04K',
#   'volumeRaw': 248044,
#   'change_precent': '3.81',
#   'last_closeRaw': '20295.79882812500000',
#   'last_openRaw': '19551.27539062500000',
#   'last_maxRaw': '20394.49023437500000',
#   'last_minRaw': '19551.23437500000000',
#   'change_precentRaw': 3.8136661674182033},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 28, 2022',
#   'rowDateRaw': 1661644800,
#   'rowDateTimestamp': '2022-08-28T00:00:00Z',
#   'last_close': '19,550.2',
#   'last_open': '20,034.2',
#   'last_max': '20,150.8',
#   'last_min': '19,542.9',
#   'volume': '159.60K',
#   'volumeRaw': 159598,
#   'change_precent': '-2.41',
#   'last_closeRaw': '19550.21875000000000',
#   'last_openRaw': '20034.22265625000000',
#   'last_maxRaw': '20150.76562500000000',
#   'last_minRaw': '19542.85742187500000',
#   'change_precentRaw': -2.4144681099146927},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 27, 2022',
#   'rowDateRaw': 1661558400,
#   'rowDateTimestamp': '2022-08-27T00:00:00Z',
#   'last_close': '20,033.9',
#   'last_open': '20,249.9',
#   'last_max': '20,343.6',
#   'last_min': '19,849.8',
#   'volume': '187.34K',
#   'volumeRaw': 187336,
#   'change_precent': '-1.07',
#   'last_closeRaw': '20033.93164062500000',
#   'last_openRaw': '20249.85156250000000',
#   'last_maxRaw': '20343.57421875000000',
#   'last_minRaw': '19849.78320312500000',
#   'change_precentRaw': -1.0663267466434232},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 26, 2022',
#   'rowDateRaw': 1661472000,
#   'rowDateTimestamp': '2022-08-26T00:00:00Z',
#   'last_close': '20,249.9',
#   'last_open': '21,564.2',
#   'last_max': '21,815.3',
#   'last_min': '20,122.4',
#   'volume': '322.16K',
#   'volumeRaw': 322155,
#   'change_precent': '-6.10',
#   'last_closeRaw': '20249.86132812500000',
#   'last_openRaw': '21564.15625000000000',
#   'last_maxRaw': '21815.28125000000000',
#   'last_minRaw': '20122.42968750000000',
#   'change_precentRaw': -6.100187656002637},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 25, 2022',
#   'rowDateRaw': 1661385600,
#   'rowDateTimestamp': '2022-08-25T00:00:00Z',
#   'last_close': '21,565.4',
#   'last_open': '21,365.4',
#   'last_max': '21,801.2',
#   'last_min': '21,324.8',
#   'volume': '190.15K',
#   'volumeRaw': 190150,
#   'change_precent': '0.94',
#   'last_closeRaw': '21565.39062500000000',
#   'last_openRaw': '21365.40039062500000',
#   'last_maxRaw': '21801.17382812500000',
#   'last_minRaw': '21324.75000000000000',
#   'change_precentRaw': 0.9370714291852235},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 24, 2022',
#   'rowDateRaw': 1661299200,
#   'rowDateTimestamp': '2022-08-24T00:00:00Z',
#   'last_close': '21,365.2',
#   'last_open': '21,516.2',
#   'last_max': '21,832.3',
#   'last_min': '21,171.1',
#   'volume': '202.40K',
#   'volumeRaw': 202403,
#   'change_precent': '-0.71',
#   'last_closeRaw': '21365.18359375000000',
#   'last_openRaw': '21516.20703125000000',
#   'last_maxRaw': '21832.25781250000000',
#   'last_minRaw': '21171.13671875000000',
#   'change_precentRaw': -0.7065743859205782},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 23, 2022',
#   'rowDateRaw': 1661212800,
#   'rowDateTimestamp': '2022-08-23T00:00:00Z',
#   'last_close': '21,517.2',
#   'last_open': '21,416.5',
#   'last_max': '21,661.0',
#   'last_min': '20,919.6',
#   'volume': '228.65K',
#   'volumeRaw': 228651,
#   'change_precent': '0.47',
#   'last_closeRaw': '21517.21875000000000',
#   'last_openRaw': '21416.45703125000000',
#   'last_maxRaw': '21661.01562500000000',
#   'last_minRaw': '20919.60937500000000',
#   'change_precentRaw': 0.4711104026043218},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 22, 2022',
#   'rowDateRaw': 1661126400,
#   'rowDateTimestamp': '2022-08-22T00:00:00Z',
#   'last_close': '21,416.3',
#   'last_open': '21,516.8',
#   'last_max': '21,517.4',
#   'last_min': '20,912.1',
#   'volume': '251.83K',
#   'volumeRaw': 251833,
#   'change_precent': '-0.47',
#   'last_closeRaw': '21416.32421875000000',
#   'last_openRaw': '21516.76757812500000',
#   'last_maxRaw': '21517.41210937500000',
#   'last_minRaw': '20912.12695312500000',
#   'change_precentRaw': -0.4690278419472752},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 21, 2022',
#   'rowDateRaw': 1661040000,
#   'rowDateTimestamp': '2022-08-21T00:00:00Z',
#   'last_close': '21,517.2',
#   'last_open': '21,138.9',
#   'last_max': '21,692.4',
#   'last_min': '21,077.4',
#   'volume': '177.52K',
#   'volumeRaw': 177522,
#   'change_precent': '1.79',
#   'last_closeRaw': '21517.24609375000000',
#   'last_openRaw': '21138.93359375000000',
#   'last_maxRaw': '21692.41992187500000',
#   'last_minRaw': '21077.39648437500000',
#   'change_precentRaw': 1.789986563920977},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 20, 2022',
#   'rowDateRaw': 1660953600,
#   'rowDateTimestamp': '2022-08-20T00:00:00Z',
#   'last_close': '21,138.9',
#   'last_open': '20,830.7',
#   'last_max': '21,357.4',
#   'last_min': '20,784.8',
#   'volume': '206.94K',
#   'volumeRaw': 206943,
#   'change_precent': '1.48',
#   'last_closeRaw': '21138.86328125000000',
#   'last_openRaw': '20830.69531250000000',
#   'last_maxRaw': '21357.37500000000000',
#   'last_minRaw': '20784.75781250000000',
#   'change_precentRaw': 1.476377445201799},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 19, 2022',
#   'rowDateRaw': 1660867200,
#   'rowDateTimestamp': '2022-08-19T00:00:00Z',
#   'last_close': '20,831.3',
#   'last_open': '23,201.6',
#   'last_max': '23,202.3',
#   'last_min': '20,807.8',
#   'volume': '339.47K',
#   'volumeRaw': 339472,
#   'change_precent': '-10.22',
#   'last_closeRaw': '20831.31445312500000',
#   'last_openRaw': '23201.57226562500000',
#   'last_maxRaw': '23202.30078125000000',
#   'last_minRaw': '20807.80664062500000',
#   'change_precentRaw': -10.223909241043547},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 18, 2022',
#   'rowDateRaw': 1660780800,
#   'rowDateTimestamp': '2022-08-18T00:00:00Z',
#   'last_close': '23,203.6',
#   'last_open': '23,337.7',
#   'last_max': '23,578.0',
#   'last_min': '23,131.3',
#   'volume': '160.97K',
#   'volumeRaw': 160969,
#   'change_precent': '-0.58',
#   'last_closeRaw': '23203.63281250000000',
#   'last_openRaw': '23337.70312500000000',
#   'last_maxRaw': '23578.02539062500000',
#   'last_minRaw': '23131.32617187500000',
#   'change_precentRaw': -0.5756110951172646},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 17, 2022',
#   'rowDateRaw': 1660694400,
#   'rowDateTimestamp': '2022-08-17T00:00:00Z',
#   'last_close': '23,338.0',
#   'last_open': '23,855.8',
#   'last_max': '24,423.5',
#   'last_min': '23,191.6',
#   'volume': '239.53K',
#   'volumeRaw': 239529,
#   'change_precent': '-2.17',
#   'last_closeRaw': '23337.96875000000000',
#   'last_openRaw': '23855.81054687500000',
#   'last_maxRaw': '24423.52343750000000',
#   'last_minRaw': '23191.59960937500000',
#   'change_precentRaw': -2.1747441889176287},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 16, 2022',
#   'rowDateRaw': 1660608000,
#   'rowDateTimestamp': '2022-08-16T00:00:00Z',
#   'last_close': '23,856.8',
#   'last_open': '24,102.6',
#   'last_max': '24,240.8',
#   'last_min': '23,693.8',
#   'volume': '201.70K',
#   'volumeRaw': 201701,
#   'change_precent': '-1.02',
#   'last_closeRaw': '23856.79296875000000',
#   'last_openRaw': '24102.61523437500000',
#   'last_maxRaw': '24240.83593750000000',
#   'last_minRaw': '23693.76171875000000',
#   'change_precentRaw': -1.0161448827968655},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 15, 2022',
#   'rowDateRaw': 1660521600,
#   'rowDateTimestamp': '2022-08-15T00:00:00Z',
#   'last_close': '24,101.7',
#   'last_open': '24,303.3',
#   'last_max': '25,205.7',
#   'last_min': '23,784.5',
#   'volume': '279.28K',
#   'volumeRaw': 279280,
#   'change_precent': '-0.83',
#   'last_closeRaw': '24101.70117187500000',
#   'last_openRaw': '24303.28710937500000',
#   'last_maxRaw': '25205.67187500000000',
#   'last_minRaw': '23784.51367187500000',
#   'change_precentRaw': -0.8275945871466069},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 14, 2022',
#   'rowDateRaw': 1660435200,
#   'rowDateTimestamp': '2022-08-14T00:00:00Z',
#   'last_close': '24,302.8',
#   'last_open': '24,442.1',
#   'last_max': '24,997.3',
#   'last_min': '24,172.2',
#   'volume': '177.25K',
#   'volumeRaw': 177252,
#   'change_precent': '-0.57',
#   'last_closeRaw': '24302.83007812500000',
#   'last_openRaw': '24442.06250000000000',
#   'last_maxRaw': '24997.25976562500000',
#   'last_minRaw': '24172.20898437500000',
#   'change_precentRaw': -0.5714065171139084},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 13, 2022',
#   'rowDateRaw': 1660348800,
#   'rowDateTimestamp': '2022-08-13T00:00:00Z',
#   'last_close': '24,442.5',
#   'last_open': '24,398.9',
#   'last_max': '24,882.9',
#   'last_min': '24,318.7',
#   'volume': '170.59K',
#   'volumeRaw': 170585,
#   'change_precent': '0.18',
#   'last_closeRaw': '24442.49609375000000',
#   'last_openRaw': '24398.86523437500000',
#   'last_maxRaw': '24882.88476562500000',
#   'last_minRaw': '24318.69140625000000',
#   'change_precentRaw': 0.17961723070223468},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 12, 2022',
#   'rowDateRaw': 1660262400,
#   'rowDateTimestamp': '2022-08-12T00:00:00Z',
#   'last_close': '24,398.7',
#   'last_open': '23,935.3',
#   'last_max': '24,440.8',
#   'last_min': '23,616.4',
#   'volume': '194.96K',
#   'volumeRaw': 194961,
#   'change_precent': '1.94',
#   'last_closeRaw': '24398.67187500000000',
#   'last_openRaw': '23935.32031250000000',
#   'last_maxRaw': '24440.84375000000000',
#   'last_minRaw': '23616.40625000000000',
#   'change_precentRaw': 1.935848597179704},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 11, 2022',
#   'rowDateRaw': 1660176000,
#   'rowDateTimestamp': '2022-08-11T00:00:00Z',
#   'last_close': '23,935.3',
#   'last_open': '23,963.3',
#   'last_max': '24,873.5',
#   'last_min': '23,864.0',
#   'volume': '285.36K',
#   'volumeRaw': 285357,
#   'change_precent': '-0.12',
#   'last_closeRaw': '23935.32031250000000',
#   'last_openRaw': '23963.29296875000000',
#   'last_maxRaw': '24873.45898437500000',
#   'last_minRaw': '23863.98828125000000',
#   'change_precentRaw': -0.11520074385741386},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 10, 2022',
#   'rowDateRaw': 1660089600,
#   'rowDateTimestamp': '2022-08-10T00:00:00Z',
#   'last_close': '23,962.9',
#   'last_open': '23,150.3',
#   'last_max': '24,209.9',
#   'last_min': '22,714.7',
#   'volume': '243.61K',
#   'volumeRaw': 243610,
#   'change_precent': '3.53',
#   'last_closeRaw': '23962.92578125000000',
#   'last_openRaw': '23150.30273437500000',
#   'last_maxRaw': '24209.88281250000000',
#   'last_minRaw': '22714.70312500000000',
#   'change_precentRaw': 3.5262670621062187},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 09, 2022',
#   'rowDateRaw': 1660003200,
#   'rowDateTimestamp': '2022-08-09T00:00:00Z',
#   'last_close': '23,146.7',
#   'last_open': '23,818.1',
#   'last_max': '23,912.0',
#   'last_min': '22,886.5',
#   'volume': '169.62K',
#   'volumeRaw': 169621,
#   'change_precent': '-2.81',
#   'last_closeRaw': '23146.71093750000000',
#   'last_openRaw': '23818.05078125000000',
#   'last_maxRaw': '23912.00781250000000',
#   'last_minRaw': '22886.47656250000000',
#   'change_precentRaw': -2.811676360391541},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 08, 2022',
#   'rowDateRaw': 1659916800,
#   'rowDateTimestamp': '2022-08-08T00:00:00Z',
#   'last_close': '23,816.3',
#   'last_open': '23,175.3',
#   'last_max': '24,234.1',
#   'last_min': '23,160.6',
#   'volume': '197.94K',
#   'volumeRaw': 197942,
#   'change_precent': '2.77',
#   'last_closeRaw': '23816.34960937500000',
#   'last_openRaw': '23175.27148437500000',
#   'last_maxRaw': '24234.07226562500000',
#   'last_minRaw': '23160.62109375000000',
#   'change_precentRaw': 2.7662162466239986},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 07, 2022',
#   'rowDateRaw': 1659830400,
#   'rowDateTimestamp': '2022-08-07T00:00:00Z',
#   'last_close': '23,175.3',
#   'last_open': '22,944.2',
#   'last_max': '23,387.7',
#   'last_min': '22,852.3',
#   'volume': '99.36K',
#   'volumeRaw': 99357,
#   'change_precent': '1.01',
#   'last_closeRaw': '23175.27148437500000',
#   'last_openRaw': '22944.20898437500000',
#   'last_maxRaw': '23387.67968750000000',
#   'last_minRaw': '22852.27929687500000',
#   'change_precentRaw': 1.0070623927691449},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 06, 2022',
#   'rowDateRaw': 1659744000,
#   'rowDateTimestamp': '2022-08-06T00:00:00Z',
#   'last_close': '22,944.2',
#   'last_open': '23,308.2',
#   'last_max': '23,344.4',
#   'last_min': '22,923.6',
#   'volume': '94.44K',
#   'volumeRaw': 94439,
#   'change_precent': '-1.56',
#   'last_closeRaw': '22944.20898437500000',
#   'last_openRaw': '23308.16406250000000',
#   'last_maxRaw': '23344.37109375000000',
#   'last_minRaw': '22923.63476562500000',
#   'change_precentRaw': -1.5614918324286187},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Aug 05, 2022',
#   'rowDateRaw': 1659657600,
#   'rowDateTimestamp': '2022-08-05T00:00:00Z',
#   'last_close': '23,308.2',
#   'last_open': '22,613.3',
#   'last_max': '23,447.6',
#   'last_min': '22,593.5',
#   'volume': '208.90K',
#   'volumeRaw': 208903,
#   'change_precent': '3.08',
#   'last_closeRaw': '23308.16406250000000',
#   'last_openRaw': '22613.26171875000000',
#   'last_maxRaw': '23447.57031250000000',
#   'last_minRaw': '22593.51757812500000',
#   'change_precentRaw': 3.078096183120655},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 04, 2022',
#   'rowDateRaw': 1659571200,
#   'rowDateTimestamp': '2022-08-04T00:00:00Z',
#   'last_close': '22,612.1',
#   'last_open': '22,822.2',
#   'last_max': '23,214.5',
#   'last_min': '22,438.7',
#   'volume': '181.19K',
#   'volumeRaw': 181186,
#   'change_precent': '-0.91',
#   'last_closeRaw': '22612.14062500000000',
#   'last_openRaw': '22822.21093750000000',
#   'last_maxRaw': '23214.46289062500000',
#   'last_minRaw': '22438.72851562500000',
#   'change_precentRaw': -0.9143419560519502},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 03, 2022',
#   'rowDateRaw': 1659484800,
#   'rowDateTimestamp': '2022-08-03T00:00:00Z',
#   'last_close': '22,820.8',
#   'last_open': '22,988.7',
#   'last_max': '23,623.7',
#   'last_min': '22,698.6',
#   'volume': '174.66K',
#   'volumeRaw': 174655,
#   'change_precent': '-0.73',
#   'last_closeRaw': '22820.80078125000000',
#   'last_openRaw': '22988.66992187500000',
#   'last_maxRaw': '23623.73046875000000',
#   'last_minRaw': '22698.58398437500000',
#   'change_precentRaw': -0.7300146964692281},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 02, 2022',
#   'rowDateRaw': 1659398400,
#   'rowDateTimestamp': '2022-08-02T00:00:00Z',
#   'last_close': '22,988.6',
#   'last_open': '23,271.1',
#   'last_max': '23,423.3',
#   'last_min': '22,670.8',
#   'volume': '177.30K',
#   'volumeRaw': 177296,
#   'change_precent': '-1.21',
#   'last_closeRaw': '22988.62109375000000',
#   'last_openRaw': '23271.07812500000000',
#   'last_maxRaw': '23423.26953125000000',
#   'last_minRaw': '22670.79492187500000',
#   'change_precentRaw': -1.2142743179458446},
#  {'direction_color': 'redFont',
#   'rowDate': 'Aug 01, 2022',
#   'rowDateRaw': 1659312000,
#   'rowDateTimestamp': '2022-08-01T00:00:00Z',
#   'last_close': '23,271.2',
#   'last_open': '23,303.4',
#   'last_max': '23,484.4',
#   'last_min': '22,863.8',
#   'volume': '162.33K',
#   'volumeRaw': 162330,
#   'change_precent': '-0.14',
#   'last_closeRaw': '23271.19726562500000',
#   'last_openRaw': '23303.42382812500000',
#   'last_maxRaw': '23484.44335937500000',
#   'last_minRaw': '22863.77734375000000',
#   'change_precentRaw': -0.13829110579495887},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 31, 2022',
#   'rowDateRaw': 1659225600,
#   'rowDateTimestamp': '2022-07-31T00:00:00Z',
#   'last_close': '23,303.4',
#   'last_open': '23,634.2',
#   'last_max': '24,179.3',
#   'last_min': '23,236.2',
#   'volume': '138.84K',
#   'volumeRaw': 138843,
#   'change_precent': '-1.40',
#   'last_closeRaw': '23303.42382812500000',
#   'last_openRaw': '23634.24804687500000',
#   'last_maxRaw': '24179.32812500000000',
#   'last_minRaw': '23236.15234375000000',
#   'change_precentRaw': -1.3993587966301082},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 30, 2022',
#   'rowDateRaw': 1659139200,
#   'rowDateTimestamp': '2022-07-30T00:00:00Z',
#   'last_close': '23,634.2',
#   'last_open': '23,774.2',
#   'last_max': '24,605.3',
#   'last_min': '23,521.8',
#   'volume': '168.72K',
#   'volumeRaw': 168721,
#   'change_precent': '-0.59',
#   'last_closeRaw': '23634.15039062500000',
#   'last_openRaw': '23774.18359375000000',
#   'last_maxRaw': '24605.25000000000000',
#   'last_minRaw': '23521.75195312500000',
#   'change_precentRaw': -0.5892995614593224},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 29, 2022',
#   'rowDateRaw': 1659052800,
#   'rowDateTimestamp': '2022-07-29T00:00:00Z',
#   'last_close': '23,774.3',
#   'last_open': '23,850.2',
#   'last_max': '24,340.0',
#   'last_min': '23,451.4',
#   'volume': '221.66K',
#   'volumeRaw': 221664,
#   'change_precent': '-0.32',
#   'last_closeRaw': '23774.25195312500000',
#   'last_openRaw': '23850.22460937500000',
#   'last_maxRaw': '24339.96484375000000',
#   'last_minRaw': '23451.40820312500000',
#   'change_precentRaw': -0.31778146364057586},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 28, 2022',
#   'rowDateRaw': 1658966400,
#   'rowDateTimestamp': '2022-07-28T00:00:00Z',
#   'last_close': '23,850.0',
#   'last_open': '22,957.7',
#   'last_max': '24,190.5',
#   'last_min': '22,611.6',
#   'volume': '268.32K',
#   'volumeRaw': 268316,
#   'change_precent': '3.88',
#   'last_closeRaw': '23850.04296875000000',
#   'last_openRaw': '22957.70117187500000',
#   'last_maxRaw': '24190.51757812500000',
#   'last_minRaw': '22611.62500000000000',
#   'change_precentRaw': 3.88408478985485},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 27, 2022',
#   'rowDateRaw': 1658880000,
#   'rowDateTimestamp': '2022-07-27T00:00:00Z',
#   'last_close': '22,958.3',
#   'last_open': '21,248.0',
#   'last_max': '23,027.8',
#   'last_min': '21,047.5',
#   'volume': '242.66K',
#   'volumeRaw': 242657,
#   'change_precent': '8.05',
#   'last_closeRaw': '22958.32226562500000',
#   'last_openRaw': '21247.99414062500000',
#   'last_maxRaw': '23027.79492187500000',
#   'last_minRaw': '21047.49804687500000',
#   'change_precentRaw': 8.045787365824724},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 26, 2022',
#   'rowDateRaw': 1658793600,
#   'rowDateTimestamp': '2022-07-26T00:00:00Z',
#   'last_close': '21,248.7',
#   'last_open': '21,301.6',
#   'last_max': '21,322.3',
#   'last_min': '20,737.3',
#   'volume': '201.57K',
#   'volumeRaw': 201568,
#   'change_precent': '-0.25',
#   'last_closeRaw': '21248.69726562500000',
#   'last_openRaw': '21301.55664062500000',
#   'last_maxRaw': '21322.26367187500000',
#   'last_minRaw': '20737.32812500000000',
#   'change_precentRaw': -0.2498399590265768},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 25, 2022',
#   'rowDateRaw': 1658707200,
#   'rowDateTimestamp': '2022-07-25T00:00:00Z',
#   'last_close': '21,301.9',
#   'last_open': '22,582.3',
#   'last_max': '22,653.3',
#   'last_min': '21,275.4',
#   'volume': '206.93K',
#   'volumeRaw': 206934,
#   'change_precent': '-5.67',
#   'last_closeRaw': '21301.91796875000000',
#   'last_openRaw': '22582.28320312500000',
#   'last_maxRaw': '22653.27539062500000',
#   'last_minRaw': '21275.38281250000000',
#   'change_precentRaw': -5.668863832322682},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 24, 2022',
#   'rowDateRaw': 1658620800,
#   'rowDateTimestamp': '2022-07-24T00:00:00Z',
#   'last_close': '22,582.1',
#   'last_open': '22,449.8',
#   'last_max': '22,987.9',
#   'last_min': '22,281.3',
#   'volume': '126.66K',
#   'volumeRaw': 126660,
#   'change_precent': '0.54',
#   'last_closeRaw': '22582.06445312500000',
#   'last_openRaw': '22449.77343750000000',
#   'last_maxRaw': '22987.93164062500000',
#   'last_minRaw': '22281.29101562500000',
#   'change_precentRaw': 0.5414814307235254},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 23, 2022',
#   'rowDateRaw': 1658534400,
#   'rowDateTimestamp': '2022-07-23T00:00:00Z',
#   'last_close': '22,460.4',
#   'last_open': '22,683.6',
#   'last_max': '22,991.0',
#   'last_min': '21,971.7',
#   'volume': '137.42K',
#   'volumeRaw': 137422,
#   'change_precent': '-0.95',
#   'last_closeRaw': '22460.44531250000000',
#   'last_openRaw': '22683.58007812500000',
#   'last_maxRaw': '22991.03906250000000',
#   'last_minRaw': '21971.67187500000000',
#   'change_precentRaw': -0.9469848032117998},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 22, 2022',
#   'rowDateRaw': 1658448000,
#   'rowDateTimestamp': '2022-07-22T00:00:00Z',
#   'last_close': '22,675.2',
#   'last_open': '23,150.0',
#   'last_max': '23,741.4',
#   'last_min': '22,524.2',
#   'volume': '197.54K',
#   'volumeRaw': 197543,
#   'change_precent': '-2.06',
#   'last_closeRaw': '22675.17578125000000',
#   'last_openRaw': '23150.01367187500000',
#   'last_maxRaw': '23741.39648437500000',
#   'last_minRaw': '22524.23046875000000',
#   'change_precentRaw': -2.0638506755244026},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 21, 2022',
#   'rowDateRaw': 1658361600,
#   'rowDateTimestamp': '2022-07-21T00:00:00Z',
#   'last_close': '23,153.0',
#   'last_open': '23,219.9',
#   'last_max': '23,403.8',
#   'last_min': '22,360.2',
#   'volume': '217.08K',
#   'volumeRaw': 217078,
#   'change_precent': '-0.27',
#   'last_closeRaw': '23153.01953125000000',
#   'last_openRaw': '23219.92187500000000',
#   'last_maxRaw': '23403.84765625000000',
#   'last_minRaw': '22360.17968750000000',
#   'change_precentRaw': -0.26785720295092186},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 20, 2022',
#   'rowDateRaw': 1658275200,
#   'rowDateTimestamp': '2022-07-20T00:00:00Z',
#   'last_close': '23,215.2',
#   'last_open': '23,412.0',
#   'last_max': '24,258.0',
#   'last_min': '22,944.4',
#   'volume': '281.31K',
#   'volumeRaw': 281308,
#   'change_precent': '-0.83',
#   'last_closeRaw': '23215.20312500000000',
#   'last_openRaw': '23411.96289062500000',
#   'last_maxRaw': '24257.96875000000000',
#   'last_minRaw': '22944.36914062500000',
#   'change_precentRaw': -0.8329866796551251},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 19, 2022',
#   'rowDateRaw': 1658188800,
#   'rowDateTimestamp': '2022-07-19T00:00:00Z',
#   'last_close': '23,410.2',
#   'last_open': '22,529.3',
#   'last_max': '23,757.3',
#   'last_min': '21,581.8',
#   'volume': '308.91K',
#   'volumeRaw': 308911,
#   'change_precent': '3.93',
#   'last_closeRaw': '23410.20703125000000',
#   'last_openRaw': '22529.26757812500000',
#   'last_maxRaw': '23757.34960937500000',
#   'last_minRaw': '21581.82226562500000',
#   'change_precentRaw': 3.9260120538652226},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 18, 2022',
#   'rowDateRaw': 1658102400,
#   'rowDateTimestamp': '2022-07-18T00:00:00Z',
#   'last_close': '22,525.8',
#   'last_open': '20,785.6',
#   'last_max': '22,714.9',
#   'last_min': '20,770.6',
#   'volume': '279.72K',
#   'volumeRaw': 279720,
#   'change_precent': '8.37',
#   'last_closeRaw': '22525.83984375000000',
#   'last_openRaw': '20785.60937500000000',
#   'last_maxRaw': '22714.89453125000000',
#   'last_minRaw': '20770.62304687500000',
#   'change_precentRaw': 8.37238689439104},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 17, 2022',
#   'rowDateRaw': 1658016000,
#   'rowDateTimestamp': '2022-07-17T00:00:00Z',
#   'last_close': '20,785.6',
#   'last_open': '21,209.8',
#   'last_max': '21,654.4',
#   'last_min': '20,755.2',
#   'volume': '132.81K',
#   'volumeRaw': 132813,
#   'change_precent': '-2.00',
#   'last_closeRaw': '20785.58984375000000',
#   'last_openRaw': '21209.76562500000000',
#   'last_maxRaw': '21654.41796875000000',
#   'last_minRaw': '20755.16796875000000',
#   'change_precentRaw': -2.000756204662943},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 16, 2022',
#   'rowDateRaw': 1657929600,
#   'rowDateTimestamp': '2022-07-16T00:00:00Z',
#   'last_close': '21,209.9',
#   'last_open': '20,825.2',
#   'last_max': '21,561.3',
#   'last_min': '20,484.4',
#   'volume': '136.89K',
#   'volumeRaw': 136885,
#   'change_precent': '1.85',
#   'last_closeRaw': '21209.94921875000000',
#   'last_openRaw': '20825.21679687500000',
#   'last_maxRaw': '21561.26757812500000',
#   'last_minRaw': '20484.42968750000000',
#   'change_precentRaw': 1.8478652124189658},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 15, 2022',
#   'rowDateRaw': 1657843200,
#   'rowDateTimestamp': '2022-07-15T00:00:00Z',
#   'last_close': '20,825.1',
#   'last_open': '20,586.1',
#   'last_max': '21,178.1',
#   'last_min': '20,393.4',
#   'volume': '164.67K',
#   'volumeRaw': 164672,
#   'change_precent': '1.16',
#   'last_closeRaw': '20825.12890625000000',
#   'last_openRaw': '20586.12500000000000',
#   'last_maxRaw': '21178.06445312500000',
#   'last_minRaw': '20393.41406250000000',
#   'change_precentRaw': 1.1615709851465403},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 14, 2022',
#   'rowDateRaw': 1657756800,
#   'rowDateTimestamp': '2022-07-14T00:00:00Z',
#   'last_close': '20,586.0',
#   'last_open': '20,250.0',
#   'last_max': '20,862.2',
#   'last_min': '19,664.9',
#   'volume': '205.28K',
#   'volumeRaw': 205284,
#   'change_precent': '1.66',
#   'last_closeRaw': '20586.00781250000000',
#   'last_openRaw': '20250.00000000000000',
#   'last_maxRaw': '20862.24609375000000',
#   'last_minRaw': '19664.92187500000000',
#   'change_precentRaw': 1.659052712546507},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 13, 2022',
#   'rowDateRaw': 1657670400,
#   'rowDateTimestamp': '2022-07-13T00:00:00Z',
#   'last_close': '20,250.0',
#   'last_open': '19,331.6',
#   'last_max': '20,250.8',
#   'last_min': '18,942.2',
#   'volume': '249.38K',
#   'volumeRaw': 249382,
#   'change_precent': '4.75',
#   'last_closeRaw': '20250.04882812500000',
#   'last_openRaw': '19331.58593750000000',
#   'last_maxRaw': '20250.77539062500000',
#   'last_minRaw': '18942.20117187500000',
#   'change_precentRaw': 4.754645066192389},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 12, 2022',
#   'rowDateRaw': 1657584000,
#   'rowDateTimestamp': '2022-07-12T00:00:00Z',
#   'last_close': '19,330.9',
#   'last_open': '19,963.2',
#   'last_max': '20,051.7',
#   'last_min': '19,279.6',
#   'volume': '167.91K',
#   'volumeRaw': 167909,
#   'change_precent': '-3.17',
#   'last_closeRaw': '19330.93164062500000',
#   'last_openRaw': '19963.21093750000000',
#   'last_maxRaw': '20051.66601562500000',
#   'last_minRaw': '19279.61914062500000',
#   'change_precentRaw': -3.167222441592758},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 11, 2022',
#   'rowDateRaw': 1657497600,
#   'rowDateTimestamp': '2022-07-11T00:00:00Z',
#   'last_close': '19,963.2',
#   'last_open': '20,847.2',
#   'last_max': '20,855.0',
#   'last_min': '19,897.0',
#   'volume': '160.20K',
#   'volumeRaw': 160196,
#   'change_precent': '-4.24',
#   'last_closeRaw': '19963.21093750000000',
#   'last_openRaw': '20847.16796875000000',
#   'last_maxRaw': '20855.00000000000000',
#   'last_minRaw': '19896.95312500000000',
#   'change_precentRaw': -4.241021322777436},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 10, 2022',
#   'rowDateRaw': 1657411200,
#   'rowDateTimestamp': '2022-07-10T00:00:00Z',
#   'last_close': '20,847.4',
#   'last_open': '21,587.4',
#   'last_max': '21,599.2',
#   'last_min': '20,689.7',
#   'volume': '204.68K',
#   'volumeRaw': 204676,
#   'change_precent': '-3.43',
#   'last_closeRaw': '20847.35156250000000',
#   'last_openRaw': '21587.40820312500000',
#   'last_maxRaw': '21599.17578125000000',
#   'last_minRaw': '20689.65039062500000',
#   'change_precentRaw': -3.428440007230759},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 09, 2022',
#   'rowDateRaw': 1657324800,
#   'rowDateTimestamp': '2022-07-09T00:00:00Z',
#   'last_close': '21,587.5',
#   'last_open': '21,610.4',
#   'last_max': '21,944.1',
#   'last_min': '21,338.4',
#   'volume': '190.11K',
#   'volumeRaw': 190109,
#   'change_precent': '-0.11',
#   'last_closeRaw': '21587.46484375000000',
#   'last_openRaw': '21610.40820312500000',
#   'last_maxRaw': '21944.08007812500000',
#   'last_minRaw': '21338.35742187500000',
#   'change_precentRaw': -0.1099237275919582},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 08, 2022',
#   'rowDateRaw': 1657238400,
#   'rowDateTimestamp': '2022-07-08T00:00:00Z',
#   'last_close': '21,611.2',
#   'last_open': '21,637.1',
#   'last_max': '22,482.1',
#   'last_min': '21,207.0',
#   'volume': '439.90K',
#   'volumeRaw': 439902,
#   'change_precent': '-0.12',
#   'last_closeRaw': '21611.22070312500000',
#   'last_openRaw': '21637.14843750000000',
#   'last_maxRaw': '22482.13671875000000',
#   'last_minRaw': '21206.98046875000000',
#   'change_precentRaw': -0.12264260282860581},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 07, 2022',
#   'rowDateRaw': 1657152000,
#   'rowDateTimestamp': '2022-07-07T00:00:00Z',
#   'last_close': '21,637.8',
#   'last_open': '20,557.9',
#   'last_max': '21,817.8',
#   'last_min': '20,282.7',
#   'volume': '115.81K',
#   'volumeRaw': 115807,
#   'change_precent': '5.24',
#   'last_closeRaw': '21637.75781250000000',
#   'last_openRaw': '20557.94726562500000',
#   'last_maxRaw': '21817.83593750000000',
#   'last_minRaw': '20282.71093750000000',
#   'change_precentRaw': 5.236314379104214},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 06, 2022',
#   'rowDateRaw': 1657065600,
#   'rowDateTimestamp': '2022-07-06T00:00:00Z',
#   'last_close': '20,561.1',
#   'last_open': '20,180.4',
#   'last_max': '20,654.9',
#   'last_min': '19,785.3',
#   'volume': '105.24K',
#   'volumeRaw': 105238,
#   'change_precent': '1.78',
#   'last_closeRaw': '20561.11328125000000',
#   'last_openRaw': '20180.38671875000000',
#   'last_maxRaw': '20654.93359375000000',
#   'last_minRaw': '19785.26757812500000',
#   'change_precentRaw': 1.7847567433565208},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 05, 2022',
#   'rowDateRaw': 1656979200,
#   'rowDateTimestamp': '2022-07-05T00:00:00Z',
#   'last_close': '20,200.6',
#   'last_open': '20,215.8',
#   'last_max': '20,706.9',
#   'last_min': '19,315.4',
#   'volume': '122.43K',
#   'volumeRaw': 122430,
#   'change_precent': '-0.08',
#   'last_closeRaw': '20200.58203125000000',
#   'last_openRaw': '20215.81640625000000',
#   'last_maxRaw': '20706.92968750000000',
#   'last_minRaw': '19315.41796875000000',
#   'change_precentRaw': -0.07535869288608142},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 04, 2022',
#   'rowDateRaw': 1656892800,
#   'rowDateTimestamp': '2022-07-04T00:00:00Z',
#   'last_close': '20,215.8',
#   'last_open': '19,310.6',
#   'last_max': '20,303.8',
#   'last_min': '19,052.5',
#   'volume': '92.79K',
#   'volumeRaw': 92789,
#   'change_precent': '4.69',
#   'last_closeRaw': '20215.81640625000000',
#   'last_openRaw': '19310.56054687500000',
#   'last_maxRaw': '20303.80859375000000',
#   'last_minRaw': '19052.48046875000000',
#   'change_precentRaw': 4.691585841402205},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jul 03, 2022',
#   'rowDateRaw': 1656806400,
#   'rowDateTimestamp': '2022-07-03T00:00:00Z',
#   'last_close': '19,309.9',
#   'last_open': '19,243.4',
#   'last_max': '19,626.4',
#   'last_min': '18,794.4',
#   'volume': '65.27K',
#   'volumeRaw': 65267,
#   'change_precent': '0.35',
#   'last_closeRaw': '19309.87695312500000',
#   'last_openRaw': '19243.43750000000000',
#   'last_maxRaw': '19626.36328125000000',
#   'last_minRaw': '18794.40625000000000',
#   'change_precentRaw': 0.3466224735108002},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 02, 2022',
#   'rowDateRaw': 1656720000,
#   'rowDateTimestamp': '2022-07-02T00:00:00Z',
#   'last_close': '19,243.2',
#   'last_open': '19,275.4',
#   'last_max': '19,425.4',
#   'last_min': '19,006.4',
#   'volume': '58.57K',
#   'volumeRaw': 58568,
#   'change_precent': '-0.10',
#   'last_closeRaw': '19243.17578125000000',
#   'last_openRaw': '19275.44140625000000',
#   'last_maxRaw': '19425.38867187500000',
#   'last_minRaw': '19006.39062500000000',
#   'change_precentRaw': -0.10250830002912006},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jul 01, 2022',
#   'rowDateRaw': 1656633600,
#   'rowDateTimestamp': '2022-07-01T00:00:00Z',
#   'last_close': '19,262.9',
#   'last_open': '19,926.6',
#   'last_max': '20,785.6',
#   'last_min': '18,980.1',
#   'volume': '150.18K',
#   'volumeRaw': 150179,
#   'change_precent': '-3.33',
#   'last_closeRaw': '19262.92187500000000',
#   'last_openRaw': '19926.55468750000000',
#   'last_maxRaw': '20785.56640625000000',
#   'last_minRaw': '18980.13281250000000',
#   'change_precentRaw': -3.3303941544711653},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jun 30, 2022',
#   'rowDateRaw': 1656547200,
#   'rowDateTimestamp': '2022-06-30T00:00:00Z',
#   'last_close': '19,926.6',
#   'last_open': '20,111.3',
#   'last_max': '20,155.1',
#   'last_min': '18,682.7',
#   'volume': '127.73K',
#   'volumeRaw': 127734,
#   'change_precent': '-0.92',
#   'last_closeRaw': '19926.55468750000000',
#   'last_openRaw': '20111.25781250000000',
# ...
#   'last_open': '9,381.5',
#   'last_max': '9,465.4',
#   'last_min': '9,183.1',
#   'volume': '683.37K',
#   'volumeRaw': 683370,
#   'change_precent': '-0.50',
#   'last_closeRaw': '9334.88671875000000',
#   'last_openRaw': '9381.53808593750000',
#   'last_maxRaw': '9465.36621093750000',
#   'last_minRaw': '9183.14257812500000',
#   'change_precentRaw': -0.4981585403060609},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Feb 01, 2020',
#   'rowDateRaw': 1580515200,
#   'rowDateTimestamp': '2020-02-01T00:00:00Z',
#   'last_close': '9,381.6',
#   'last_open': '9,349.3',
#   'last_max': '9,458.8',
#   'last_min': '9,301.5',
#   'volume': '458.42K',
#   'volumeRaw': 458416,
#   'change_precent': '0.35',
#   'last_closeRaw': '9381.62207031250000',
#   'last_openRaw': '9349.29687500000000',
#   'last_maxRaw': '9458.78808593750000',
#   'last_minRaw': '9301.46582031250000',
#   'change_precentRaw': 0.3474165878990603},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 31, 2020',
#   'rowDateRaw': 1580428800,
#   'rowDateTimestamp': '2020-01-31T00:00:00Z',
#   'last_close': '9,349.1',
#   'last_open': '9,508.3',
#   'last_max': '9,525.0',
#   'last_min': '9,222.3',
#   'volume': '633.37K',
#   'volumeRaw': 633368,
#   'change_precent': '-1.66',
#   'last_closeRaw': '9349.14160156250000',
#   'last_openRaw': '9508.26562500000000',
#   'last_maxRaw': '9525.01171875000000',
#   'last_minRaw': '9222.31738281250000',
#   'change_precentRaw': -1.6632519968782118},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 30, 2020',
#   'rowDateRaw': 1580342400,
#   'rowDateTimestamp': '2020-01-30T00:00:00Z',
#   'last_close': '9,507.3',
#   'last_open': '9,299.1',
#   'last_max': '9,569.0',
#   'last_min': '9,209.2',
#   'volume': '765.21K',
#   'volumeRaw': 765205,
#   'change_precent': '2.24',
#   'last_closeRaw': '9507.27148437500000',
#   'last_openRaw': '9299.12304687500000',
#   'last_maxRaw': '9568.98242187500000',
#   'last_minRaw': '9209.16113281250000',
#   'change_precentRaw': 2.2407499201855057},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 29, 2020',
#   'rowDateRaw': 1580256000,
#   'rowDateTimestamp': '2020-01-29T00:00:00Z',
#   'last_close': '9,298.9',
#   'last_open': '9,377.3',
#   'last_max': '9,428.7',
#   'last_min': '9,250.9',
#   'volume': '749.88K',
#   'volumeRaw': 749884,
#   'change_precent': '-0.84',
#   'last_closeRaw': '9298.90625000000000',
#   'last_openRaw': '9377.26855468750000',
#   'last_maxRaw': '9428.69042968750000',
#   'last_minRaw': '9250.92675781250000',
#   'change_precentRaw': -0.8359412018932866},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 28, 2020',
#   'rowDateRaw': 1580169600,
#   'rowDateTimestamp': '2020-01-28T00:00:00Z',
#   'last_close': '9,377.3',
#   'last_open': '8,866.6',
#   'last_max': '9,389.5',
#   'last_min': '8,866.6',
#   'volume': '954.20K',
#   'volumeRaw': 954201,
#   'change_precent': '5.76',
#   'last_closeRaw': '9377.29492187500000',
#   'last_openRaw': '8866.61914062500000',
#   'last_maxRaw': '9389.45605468750000',
#   'last_minRaw': '8866.61914062500000',
#   'change_precentRaw': 5.760137877468537},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 27, 2020',
#   'rowDateRaw': 1580083200,
#   'rowDateTimestamp': '2020-01-27T00:00:00Z',
#   'last_close': '8,866.6',
#   'last_open': '8,608.1',
#   'last_max': '8,983.1',
#   'last_min': '8,585.6',
#   'volume': '706.45K',
#   'volumeRaw': 706451,
#   'change_precent': '3.01',
#   'last_closeRaw': '8866.56835937500000',
#   'last_openRaw': '8608.09179687500000',
#   'last_maxRaw': '8983.13085937500000',
#   'last_minRaw': '8585.56640625000000',
#   'change_precentRaw': 3.005894662991777},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 26, 2020',
#   'rowDateRaw': 1579996800,
#   'rowDateTimestamp': '2020-01-26T00:00:00Z',
#   'last_close': '8,607.8',
#   'last_open': '8,341.6',
#   'last_max': '8,607.8',
#   'last_min': '8,304.9',
#   'volume': '468.34K',
#   'volumeRaw': 468343,
#   'change_precent': '3.19',
#   'last_closeRaw': '8607.82617187500000',
#   'last_openRaw': '8341.61718750000000',
#   'last_maxRaw': '8607.82617187500000',
#   'last_minRaw': '8304.90429687500000',
#   'change_precentRaw': 3.1915287176005056},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 25, 2020',
#   'rowDateRaw': 1579910400,
#   'rowDateTimestamp': '2020-01-25T00:00:00Z',
#   'last_close': '8,341.6',
#   'last_open': '8,439.9',
#   'last_max': '8,447.6',
#   'last_min': '8,277.2',
#   'volume': '444.00K',
#   'volumeRaw': 443997,
#   'change_precent': '-1.17',
#   'last_closeRaw': '8341.60156250000000',
#   'last_openRaw': '8439.94433593750000',
#   'last_maxRaw': '8447.58593750000000',
#   'last_minRaw': '8277.24218750000000',
#   'change_precentRaw': -1.1650234475331},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 24, 2020',
#   'rowDateRaw': 1579824000,
#   'rowDateTimestamp': '2020-01-24T00:00:00Z',
#   'last_close': '8,439.9',
#   'last_open': '8,404.9',
#   'last_max': '8,522.0',
#   'last_min': '8,242.6',
#   'volume': '617.02K',
#   'volumeRaw': 617019,
#   'change_precent': '0.41',
#   'last_closeRaw': '8439.92871093750000',
#   'last_openRaw': '8404.87792968750000',
#   'last_maxRaw': '8522.00683593750000',
#   'last_minRaw': '8242.62597656250000',
#   'change_precentRaw': 0.41448559414501046},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 23, 2020',
#   'rowDateRaw': 1579737600,
#   'rowDateTimestamp': '2020-01-23T00:00:00Z',
#   'last_close': '8,405.1',
#   'last_open': '8,678.5',
#   'last_max': '8,687.3',
#   'last_min': '8,309.6',
#   'volume': '722.67K',
#   'volumeRaw': 722670,
#   'change_precent': '-3.15',
#   'last_closeRaw': '8405.09082031250000',
#   'last_openRaw': '8678.52539062500000',
#   'last_maxRaw': '8687.28125000000000',
#   'last_minRaw': '8309.55859375000000',
#   'change_precentRaw': -3.1502345003531658},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 22, 2020',
#   'rowDateRaw': 1579651200,
#   'rowDateTimestamp': '2020-01-22T00:00:00Z',
#   'last_close': '8,678.5',
#   'last_open': '8,733.0',
#   'last_max': '8,805.4',
#   'last_min': '8,610.8',
#   'volume': '509.06K',
#   'volumeRaw': 509057,
#   'change_precent': '-0.62',
#   'last_closeRaw': '8678.48339843750000',
#   'last_openRaw': '8732.96191406250000',
#   'last_maxRaw': '8805.38867187500000',
#   'last_minRaw': '8610.79882812500000',
#   'change_precentRaw': -0.6202367865733716},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 21, 2020',
#   'rowDateRaw': 1579564800,
#   'rowDateTimestamp': '2020-01-21T00:00:00Z',
#   'last_close': '8,732.6',
#   'last_open': '8,642.0',
#   'last_max': '8,770.3',
#   'last_min': '8,524.0',
#   'volume': '540.20K',
#   'volumeRaw': 540202,
#   'change_precent': '1.05',
#   'last_closeRaw': '8732.64648437500000',
#   'last_openRaw': '8641.96972656250000',
#   'last_maxRaw': '8770.26953125000000',
#   'last_minRaw': '8524.01562500000000',
#   'change_precentRaw': 1.050516387402482},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 20, 2020',
#   'rowDateRaw': 1579478400,
#   'rowDateTimestamp': '2020-01-20T00:00:00Z',
#   'last_close': '8,641.9',
#   'last_open': '8,705.7',
#   'last_max': '8,740.1',
#   'last_min': '8,539.2',
#   'volume': '599.06K',
#   'volumeRaw': 599057,
#   'change_precent': '-0.74',
#   'last_closeRaw': '8641.86230468750000',
#   'last_openRaw': '8705.73437500000000',
#   'last_maxRaw': '8740.14062500000000',
#   'last_minRaw': '8539.18359375000000',
#   'change_precentRaw': -0.7393901528683925},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 19, 2020',
#   'rowDateRaw': 1579392000,
#   'rowDateTimestamp': '2020-01-19T00:00:00Z',
#   'last_close': '8,706.2',
#   'last_open': '8,916.3',
#   'last_max': '9,183.7',
#   'last_min': '8,552.8',
#   'volume': '975.01K',
#   'volumeRaw': 975005,
#   'change_precent': '-2.36',
#   'last_closeRaw': '8706.23535156250000',
#   'last_openRaw': '8916.33300781250000',
#   'last_maxRaw': '9183.68652343750000',
#   'last_minRaw': '8552.83593750000000',
#   'change_precentRaw': -2.355874401702554},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 18, 2020',
#   'rowDateRaw': 1579305600,
#   'rowDateTimestamp': '2020-01-18T00:00:00Z',
#   'last_close': '8,916.3',
#   'last_open': '8,913.0',
#   'last_max': '8,982.3',
#   'last_min': '8,814.6',
#   'volume': '627.74K',
#   'volumeRaw': 627743,
#   'change_precent': '0.04',
#   'last_closeRaw': '8916.29199218750000',
#   'last_openRaw': '8912.97851562500000',
#   'last_maxRaw': '8982.27246093750000',
#   'last_minRaw': '8814.64843750000000',
#   'change_precentRaw': 0.035498901451433945},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 17, 2020',
#   'rowDateRaw': 1579219200,
#   'rowDateTimestamp': '2020-01-17T00:00:00Z',
#   'last_close': '8,913.1',
#   'last_open': '8,726.7',
#   'last_max': '9,005.1',
#   'last_min': '8,675.9',
#   'volume': '794.11K',
#   'volumeRaw': 794106,
#   'change_precent': '2.13',
#   'last_closeRaw': '8913.12792968750000',
#   'last_openRaw': '8726.65820312500000',
#   'last_maxRaw': '9005.08007812500000',
#   'last_minRaw': '8675.93847656250000',
#   'change_precentRaw': 2.134176841802772},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 16, 2020',
#   'rowDateRaw': 1579132800,
#   'rowDateTimestamp': '2020-01-16T00:00:00Z',
#   'last_close': '8,726.9',
#   'last_open': '8,818.1',
#   'last_max': '8,850.0',
#   'last_min': '8,605.8',
#   'volume': '748.32K',
#   'volumeRaw': 748321,
#   'change_precent': '-1.04',
#   'last_closeRaw': '8726.88085937500000',
#   'last_openRaw': '8818.06738281250000',
#   'last_maxRaw': '8849.95898437500000',
#   'last_minRaw': '8605.77343750000000',
#   'change_precentRaw': -1.0365204664535899},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 15, 2020',
#   'rowDateRaw': 1579046400,
#   'rowDateTimestamp': '2020-01-15T00:00:00Z',
#   'last_close': '8,818.3',
#   'last_open': '8,827.9',
#   'last_max': '8,904.0',
#   'last_min': '8,615.5',
#   'volume': '1.17M',
#   'volumeRaw': 1172542,
#   'change_precent': '-0.12',
#   'last_closeRaw': '8818.28417968750000',
#   'last_openRaw': '8827.94726562500000',
#   'last_maxRaw': '8904.00878906250000',
#   'last_minRaw': '8615.49707031250000',
#   'change_precentRaw': -0.12319350571796828},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 14, 2020',
#   'rowDateRaw': 1578960000,
#   'rowDateTimestamp': '2020-01-14T00:00:00Z',
#   'last_close': '8,829.2',
#   'last_open': '8,111.2',
#   'last_max': '8,898.7',
#   'last_min': '8,111.2',
#   'volume': '1.48M',
#   'volumeRaw': 1482862,
#   'change_precent': '8.85',
#   'last_closeRaw': '8829.16113281250000',
#   'last_openRaw': '8111.24755859375000',
#   'last_maxRaw': '8898.69531250000000',
#   'last_minRaw': '8111.24755859375000',
#   'change_precentRaw': 8.849411930000464},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 13, 2020',
#   'rowDateRaw': 1578873600,
#   'rowDateTimestamp': '2020-01-13T00:00:00Z',
#   'last_close': '8,111.4',
#   'last_open': '8,188.3',
#   'last_max': '8,196.7',
#   'last_min': '8,068.4',
#   'volume': '610.66K',
#   'volumeRaw': 610664,
#   'change_precent': '-0.93',
#   'last_closeRaw': '8111.35400390625000',
#   'last_openRaw': '8188.33447265625000',
#   'last_maxRaw': '8196.66015625000000',
#   'last_minRaw': '8068.43359375000000',
#   'change_precentRaw': -0.9311854417732236},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 12, 2020',
#   'rowDateRaw': 1578787200,
#   'rowDateTimestamp': '2020-01-12T00:00:00Z',
#   'last_close': '8,187.6',
#   'last_open': '8,023.3',
#   'last_max': '8,189.9',
#   'last_min': '7,973.1',
#   'volume': '595.22K',
#   'volumeRaw': 595217,
#   'change_precent': '2.04',
#   'last_closeRaw': '8187.59570312500000',
#   'last_openRaw': '8023.26367187500000',
#   'last_maxRaw': '8189.87988281250000',
#   'last_minRaw': '7973.13378906250000',
#   'change_precentRaw': 2.0374948116232052},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 11, 2020',
#   'rowDateRaw': 1578700800,
#   'rowDateTimestamp': '2020-01-11T00:00:00Z',
#   'last_close': '8,024.1',
#   'last_open': '8,187.8',
#   'last_max': '8,262.9',
#   'last_min': '8,008.4',
#   'volume': '776.75K',
#   'volumeRaw': 776750,
#   'change_precent': '-1.99',
#   'last_closeRaw': '8024.10498046875000',
#   'last_openRaw': '8187.83300781250000',
#   'last_maxRaw': '8262.94433593750000',
#   'last_minRaw': '8008.44531250000000',
#   'change_precentRaw': -1.990666866660961},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 10, 2020',
#   'rowDateRaw': 1578614400,
#   'rowDateTimestamp': '2020-01-10T00:00:00Z',
#   'last_close': '8,187.1',
#   'last_open': '7,842.5',
#   'last_max': '8,187.4',
#   'last_min': '7,697.7',
#   'volume': '1.05M',
#   'volumeRaw': 1049642,
#   'change_precent': '4.40',
#   'last_closeRaw': '8187.08251953125000',
#   'last_openRaw': '7842.51171875000000',
#   'last_maxRaw': '8187.39306640625000',
#   'last_minRaw': '7697.69482421875000',
#   'change_precentRaw': 4.395240061524607},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 09, 2020',
#   'rowDateRaw': 1578528000,
#   'rowDateTimestamp': '2020-01-09T00:00:00Z',
#   'last_close': '7,842.4',
#   'last_open': '8,060.0',
#   'last_max': '8,065.9',
#   'last_min': '7,779.2',
#   'volume': '786.50K',
#   'volumeRaw': 786500,
#   'change_precent': '-2.70',
#   'last_closeRaw': '7842.39062500000000',
#   'last_openRaw': '8059.95166015625000',
#   'last_maxRaw': '8065.89648437500000',
#   'last_minRaw': '7779.21386718750000',
#   'change_precentRaw': -2.695559091342263},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 08, 2020',
#   'rowDateRaw': 1578441600,
#   'rowDateTimestamp': '2020-01-08T00:00:00Z',
#   'last_close': '8,059.6',
#   'last_open': '8,154.2',
#   'last_max': '8,436.4',
#   'last_min': '7,900.8',
#   'volume': '1.19M',
#   'volumeRaw': 1188887,
#   'change_precent': '-1.18',
#   'last_closeRaw': '8059.64306640625000',
#   'last_openRaw': '8154.23681640625000',
#   'last_maxRaw': '8436.43554687500000',
#   'last_minRaw': '7900.75927734375000',
#   'change_precentRaw': -1.1778149849385238},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 07, 2020',
#   'rowDateRaw': 1578355200,
#   'rowDateTimestamp': '2020-01-07T00:00:00Z',
#   'last_close': '8,155.7',
#   'last_open': '7,759.1',
#   'last_max': '8,182.0',
#   'last_min': '7,754.1',
#   'volume': '1.01M',
#   'volumeRaw': 1013985,
#   'change_precent': '5.11',
#   'last_closeRaw': '8155.70214843750000',
#   'last_openRaw': '7759.11718750000000',
#   'last_maxRaw': '8181.98583984375000',
#   'last_minRaw': '7754.05908203125000',
#   'change_precentRaw': 5.1119069571274585},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 06, 2020',
#   'rowDateRaw': 1578268800,
#   'rowDateTimestamp': '2020-01-06T00:00:00Z',
#   'last_close': '7,759.1',
#   'last_open': '7,372.6',
#   'last_max': '7,783.1',
#   'last_min': '7,366.7',
#   'volume': '786.75K',
#   'volumeRaw': 786750,
#   'change_precent': '5.24',
#   'last_closeRaw': '7759.06591796875000',
#   'last_openRaw': '7372.63623046875000',
#   'last_maxRaw': '7783.08300781250000',
#   'last_minRaw': '7366.72265625000000',
#   'change_precentRaw': 5.242889139414102},
#  {'direction_color': 'redFont',
#   'rowDate': 'Jan 05, 2020',
#   'rowDateRaw': 1578182400,
#   'rowDateTimestamp': '2020-01-05T00:00:00Z',
#   'last_close': '7,372.5',
#   'last_open': '7,376.8',
#   'last_max': '7,501.0',
#   'last_min': '7,345.6',
#   'volume': '628.14K',
#   'volumeRaw': 628142,
#   'change_precent': '-0.06',
#   'last_closeRaw': '7372.53222656250000',
#   'last_openRaw': '7376.79785156250000',
#   'last_maxRaw': '7501.04101562500000',
#   'last_minRaw': '7345.59179687500000',
#   'change_precentRaw': -0.05718981179388951},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 04, 2020',
#   'rowDateRaw': 1578096000,
#   'rowDateTimestamp': '2020-01-04T00:00:00Z',
#   'last_close': '7,376.8',
#   'last_open': '7,345.1',
#   'last_max': '7,433.1',
#   'last_min': '7,291.4',
#   'volume': '523.91K',
#   'volumeRaw': 523909,
#   'change_precent': '0.46',
#   'last_closeRaw': '7376.75097656250000',
#   'last_openRaw': '7345.07910156250000',
#   'last_maxRaw': '7433.07080078125000',
#   'last_minRaw': '7291.44433593750000',
#   'change_precentRaw': 0.45819848937529684},
#  {'direction_color': 'greenFont',
#   'rowDate': 'Jan 03, 2020',
#   'rowDateRaw': 1578009600,
#   'rowDateTimestamp': '2020-01-03T00:00:00Z',
#   'last_close': '7,343.1',
#   'last_open': '6,967.1',
#   'last_max': '7,402.9',
#   'last_min': '6,884.1',
#   'volume': '936.29K',
#   'volumeRaw': 936288,
#   'change_precent': '5.40',
#   'last_closeRaw': '7343.10498046875000',
#   'last_openRaw': '6967.07080078125000',
#   'last_maxRaw': '7402.89111328125000',
#   'last_minRaw': '6884.06396484375000',
#   'change_precentRaw': 5.398207890856176},
#  ...]

# %%
scraper.export_data()

# %%
with open('prices.json', 'r') as file:
    f = json.load(file)
